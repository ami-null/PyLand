# %% [markdown]
# Name:
#
# ID:

# %%
student_id = 2000127999

# %% [markdown]
# # Q1

# %% [markdown]
# # Q2

# %% [markdown]
# # Q3

# %% [markdown]
# # Q4

# %% [markdown]
# ## A

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from gendf import random_theme_df

# %%
df = random_theme_df(student_id)
